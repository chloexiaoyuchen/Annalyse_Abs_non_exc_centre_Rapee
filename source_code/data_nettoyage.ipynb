# %% [markdown]
# # Data netoyage et preparation
# - Read the input data  'export_rdv_2023-01-01-2023-12-31.csv'
# - Extract the features and labels
# - Clean the data
# - Return 2023_gold.csv, 2023_silver.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import openpyxl
from datetime import datetime

sns.set_theme("notebook")

# %%
df = pd.read_csv('../données_brut/export_rdv_2023-01-01-2023-12-31.csv', sep=';')
df.head()
# Out:
# /tmp/ipykernel_56972/3073084613.py:1: DtypeWarning: Columns (45,46,47,48,49,50) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../données_brut/export_rdv_2023-01-01-2023-12-31.csv', sep=';')
#            Id  Doctolib Patient ID Date de début  Début  Durée du RDV  \
# 0  4276042583           1733349697    02/01/2023  09h00            15
# 1  4279470930           2518302311    02/01/2023  09h00            20
# 2  4192809235           2435238586    02/01/2023  09h00            15
# 3  4279779300           2518370353    02/01/2023  09h15            20
# 4  4277334926           2053339522    02/01/2023  09h15            15
#
#                   Agenda                                Motif du RDV  \
# 0  MEKHATRIA Sid (Rapée)  Adulte - Consultation de médecine générale
# 1    MEYKIECHEL Tiphaine        Première consultation de gynécologie
# 2            COSTES Jean        Consultation de suivi d'allergologie
# 3            COSTES Jean                                     Urgence
# 4  MEKHATRIA Sid (Rapée)  Adulte - Consultation de médecine générale
#
#            Notes                 Date de saisie  \
# 0            NaN  2022-12-29T22:42:54.715+01:00
# 1  APC + JKHD001  2023-01-01T16:56:55.308+01:00
# 2            NaN  2022-11-30T09:13:05.365+01:00
# 3              A  2023-01-01T22:58:13.205+01:00
# 4            NaN  2022-12-30T18:22:52.683+01:00
#
#     Date de dernière mise à jour  ...  \
# 0  2023-01-24T12:00:24.044+01:00  ...
# 1  2023-01-02T09:47:45.981+01:00  ...
# 2  2023-01-02T09:46:57.770+01:00  ...
# 3  2023-01-02T09:47:33.129+01:00  ...
# 4  2023-01-02T09:11:26.923+01:00  ...
#
#   Présentez-vous des troubles de l'hémostase (taux de plaquette bas, maladie spécifique) ?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Précisez le type d'injection Identifiant Externe  \
# 0                          NaN                 NaN
# 1                          NaN                 NaN
# 2                          NaN                 NaN
# 3                          NaN                 NaN
# 4                          NaN                 NaN
#
#   Temps de réservation en secondes  A été importé  \
# 0                              NaN            NaN
# 1                              NaN            NaN
# 2                              NaN            NaN
# 3                              NaN            NaN
# 4                              NaN            NaN
#
#    A été réservé lors d'une absence  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    A été réservé sur un créneau horaire déjà réservé  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    A été réservé en dehors des horaires d'ouverture  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    Dispositif de réservation pour les patients  Personne référente
# 0                                          NaN                 NaN
# 1                                          NaN                 NaN
# 2                                          NaN                 NaN
# 3                                          NaN                 NaN
# 4                                          NaN                 NaN
#
# [5 rows x 51 columns]

# %%
df2 = df[["Id","Date de début","Début", "Durée du RDV", "Motif du RDV", "RDV Internet", "Nouveau patient", 
          "Date de naissance", "Adresse", "Code postal", "Ville", "Statut", "Civilité"]]

df2['Adresse complète'] = df2['Adresse'] + ', ' + df2['Code postal'] + ' ' + df2['Ville']
df2.drop(['Adresse', 'Code postal', 'Ville'], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_56972/4194803853.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Adresse complète'] = df2['Adresse'] + ', ' + df2['Code postal'] + ' ' + df2['Ville']
# /tmp/ipykernel_56972/4194803853.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(['Adresse', 'Code postal', 'Ville'], axis=1, inplace=True)

# %%
# Calculate age
df2['Age'] = 2024 - pd.to_datetime(df2['Date de naissance']).dt.year

# Drop the 'Date de naissance' column
df2.drop('Date de naissance', axis=1, inplace=True)
# Out:
# /tmp/ipykernel_56972/432343894.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Age'] = 2024 - pd.to_datetime(df2['Date de naissance']).dt.year
# /tmp/ipykernel_56972/432343894.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop('Date de naissance', axis=1, inplace=True)

# %%
day_map = {
    'Mon': 'Lun',
    'Tue': 'Mar',
    'Wed': 'Mer',
    'Thu': 'Jeu',
    'Fri': 'Ven',
    'Sat': 'Sam',
    'Sun': 'Dim'
}

df2['Date de début'] = pd.to_datetime(df2['Date de début'], format='%d/%m/%Y')
df2['Date de début'] = df2['Date de début'].dt.strftime('%a').map(day_map)
# Out:
# /tmp/ipykernel_56972/1968794957.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Date de début'] = pd.to_datetime(df2['Date de début'], format='%d/%m/%Y')
# /tmp/ipykernel_56972/1968794957.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Date de début'] = df2['Date de début'].dt.strftime('%a').map(day_map)

# %%
# def get_traval_time(origin):
#     # Replace 'YOUR_API_KEY' with your actual Google Maps API key
#     gmaps = googlemaps.Client(key='AIzaSyDd9UANXP__SxMwhZe5oqTlW3YF7cIIB6s')

#     # Define the addresses or coordinates of the starting and ending points
#     #origin = "100 Quai de la Rapée, 75012 Paris"
#     destination = "100 Quai de la Rapée, 75012 Paris"

#     # Specify the departure time (optional, defaults to current time)
#     departure_time = datetime.now()
#     try:
#         # Get the travel time using the Distance Matrix API
#         result = gmaps.distance_matrix(origins=origin, destinations=destination, departure_time=departure_time, mode="transit")

#         # Extract the duration from the result
#         if result['status'] == 'OK':
#             #print("result:", result)
#             duration_in_traffic = result['rows'][0]['elements'][0]['duration']['text']  
#             #print("Estimated travel time in current traffic:", duration_in_traffic)
#             if "hour" in duration_in_traffic:
#                 time = int(duration_in_traffic.split(" ")[0])*60 + int(duration_in_traffic.split(" ")[2])
#             else:
#                 time = int(duration_in_traffic.split(" ")[0])
#             if time < 90:
#                 return time
#             else:
#                 return None
#             #return int(duration_in_traffic.split(" ")[0])
#             #print("Estimated travel time in current traffic:", duration_in_traffic)
            
#         else:
#             print("Error:", result['status'])
#             return None
#     except Exception as e:
#         print("Error:", e)

#         return None
    
# #df2.loc[:, 'voyage dans le temps'] = df2['Adresse complète'].apply(get_traval_time)

# %%
df2.to_csv('../donnees_nettroye/2023_silver.csv', index=False)

# %%
def convert_time_to_string(time):
    hour = int(time[:2])
    if hour < 12:
        return "matin"
    elif hour < 18:
        return "apres-midi"
    else:
        return "soir"

# Apply the function to the "rdv_time" column
df2['Début'] = df2['Début'].apply(convert_time_to_string)
# Out:
# /tmp/ipykernel_56972/1645600965.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Début'] = df2['Début'].apply(convert_time_to_string)

# %%
df2.head()
# Out:
#            Id Date de début  Début  Durée du RDV  \
# 0  4276042583       workday  matin            15
# 1  4279470930       workday  matin            20
# 2  4192809235       workday  matin            15
# 3  4279779300       workday  matin            20
# 4  4277334926       workday  matin            15
#
#                                  Motif du RDV RDV Internet Nouveau patient  \
# 0  Adulte - Consultation de médecine générale          Oui             Non
# 1        Première consultation de gynécologie          Oui             Non
# 2        Consultation de suivi d'allergologie          Non             Non
# 3                                     Urgence          Oui             Oui
# 4  Adulte - Consultation de médecine générale          Oui             Non
#
#           Statut Civilité                               Adresse complète   Age
# 0  Absent excusé      Mme                    13 rue de KONNA, 35740 PACE  26.0
# 1        Présent      Mme                 32 rue du javelot, 75013 paris  34.0
# 2        Présent       M.  44 av JB Clément , 92100 BOULOGNE BILLANCOURT  29.0
# 3        Présent       M.     31 rue Charles tillon, 93300 AUBERVILLIERS  31.0
# 4  Absent excusé       M.             74 Rue de la Colonie , 75013 PARIS  34.0

# %%
day_map = {
    'Lun': 'workday',
    'Mar': 'workday',
    'Mer': 'workday',
    'Jeu': 'workday',
    'Ven': 'workday',
    'Sam': 'weekend',
    'Dim': 'weekend'
}

df2['Date de début'] = df2['Date de début'].map(day_map)
# Out:
# /tmp/ipykernel_56972/2406071929.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Date de début'] = df2['Date de début'].map(day_map)

# %%
day_map = {
    'Absent excusé': 'Absent excusé',
    'Absent non excusé': 'Absent non excusé',
    'Vu' : 'Présent',
    'À déplacer': 'Absent excusé',
    'À venir': 'Absent non excusé',
    'En attente': 'Présent',
    'En consultation': 'Présent'    
}

df2['Statut'] = df2['Statut'].map(day_map)
# Out:
# /tmp/ipykernel_56972/3895112586.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Statut'] = df2['Statut'].map(day_map)

# %%
df2.dropna(inplace=True)
# Out:
# /tmp/ipykernel_56972/1761232742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(inplace=True)

# %%
df2.to_csv('../donnees_nettroye/2023_gold.csv', index=False)
